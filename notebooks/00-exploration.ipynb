# %% [markdown]
# I'm going to do some data exploration for the dat files

# %%
# %pip install pandas
# %pip install pyreadr
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 50.2 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyreadr
#import pandas as pd
result_te_ff = pyreadr.read_r('c:/Users/dmend/OneDrive/Bagage/Courses/pharma-lakehouse-portfolio/data/raw/TEP_FaultFree_Testing.RData')
result_te_f = pyreadr.read_r('c:/Users/dmend/OneDrive/Bagage/Courses/pharma-lakehouse-portfolio/data/raw/TEP_Faulty_Testing.RData')
result_tr_ff = pyreadr.read_r('c:/Users/dmend/OneDrive/Bagage/Courses/pharma-lakehouse-portfolio/data/raw/TEP_FaultFree_Training.RData')
result_tr_f = pyreadr.read_r('c:/Users/dmend/OneDrive/Bagage/Courses/pharma-lakehouse-portfolio/data/raw/TEP_Faulty_Training.RData')

# %%
df_tr_ff = result_tr_ff['fault_free_training']
df_te_ff = result_te_ff['fault_free_testing']
df_tr_f = result_tr_f['faulty_training']
df_te_f = result_te_f['faulty_testing']

# %%
df_te_ff.head()

#df_f['simulationRun'].unique()
# Out:
#    faultNumber  simulationRun  sample  xmeas_1  xmeas_2  xmeas_3  xmeas_4  \
# 0            0            1.0       1  0.25171   3672.4   4466.3   9.5122
# 1            0            1.0       2  0.25234   3642.2   4568.7   9.4145
# 2            0            1.0       3  0.24840   3643.1   4507.5   9.2901
# 3            0            1.0       4  0.25153   3628.3   4519.3   9.3347
# 4            0            1.0       5  0.21763   3655.8   4571.0   9.3087
#
#    xmeas_5  xmeas_6  xmeas_7  ...   xmv_2   xmv_3   xmv_4   xmv_5   xmv_6  \
# 0   27.057   42.473   2705.6  ...  54.494  24.527  59.710  22.357  40.149
# 1   26.999   42.586   2705.2  ...  53.269  24.465  60.466  22.413  39.956
# 2   26.927   42.278   2703.5  ...  54.000  24.860  60.642  22.199  40.074
# 3   26.999   42.330   2703.9  ...  53.860  24.553  61.908  21.981  40.141
# 4   26.901   42.402   2707.7  ...  53.307  21.775  61.891  22.412  37.696
#
#     xmv_7   xmv_8   xmv_9  xmv_10  xmv_11
# ...
